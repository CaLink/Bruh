# %% [markdown]
# # Init

# %%
import pandas as pd

from matplotlib import pylab
import numpy as np

csv = 'Dataset.csv'

# %% [markdown]
# # Preparing

# %%
#orig = pd.read_csv(csv)
tab = pd.read_csv(csv,index_col="PassengerId")

#Delete all NaN Row
tab = tab.dropna()

# %% [markdown]
# # Description

# %%
#3
tHead = list(tab.columns)
tType = tab.dtypes

print(tHead, '\n')

print(tType)
# Out:
# ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
#4
print(tab.describe())
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean     0.672131    1.191257   35.674426    0.464481    0.475410   78.682469
# std      0.470725    0.515187   15.643866    0.644159    0.754617   76.347843
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
#5
graph = tab.hist(column="Age",color = "red")

#IDK
for ax in graph.flatten():
    ax.set_xlabel("Age")
    ax.set_ylabel("Count")

print(graph)
# Out:
# [[<AxesSubplot:title={'center':'Age'}, xlabel='Age', ylabel='Count'>]]

# %%
#6
print(tab['Fare'].describe())
# Out:
# count    183.000000
# mean      78.682469
# std       76.347843
# min        0.000000
# 25%       29.700000
# 50%       57.000000
# 75%       90.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# # Column and Row

# %%
#7
print(tHead)
# Out:
# ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
#8
tab = tab.rename(columns={"Pclass":"Class"})
tab
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
#9
female = tab[tab.Sex == "female"]
female
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 11                  1      3
# 12                  1      1
# 53                  1      1
# ...               ...    ...
# 854                 1      1
# 863                 1      1
# 872                 1      1
# 880                 1      1
# 888                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# ...                                                        ...     ...   ...
# ...

# %%
#10
Ymale = tab[(tab.Survived == 1) & (tab.Age < 32) & (tab.Sex == "male")]
Ymale
# Out:
#              Survived  Class                                       Name   Sex  \
# PassengerId
# 24                  1      1               Sloper, Mr. William Thompson  male
# 98                  1      1            Greenfield, Mr. William Bertram  male
# 184                 1      2                  Becker, Master. Richard F  male
# 194                 1      2                 Navratil, Master. Michel M  male
# 306                 1      1             Allison, Master. Hudson Trevor  male
# 341                 1      2             Navratil, Master. Edmond Roger  male
# 371                 1      1                Harder, Mr. George Achilles  male
# 431                 1      1  Bjornstrom-Steffansson, Mr. Mauritz Hakan  male
# 446                 1      1                  Dodge, Master. Washington  male
# 485                 1      1                    Bishop, Mr. Dickinson H  male
# 551                 1      1                Thayer, Mr. John Borland Jr  male
# ...

# %%
#11
tab[(tab.Class == 1) | (tab.Class == 2)]
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 12                  1      1
# 22                  1      2
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# ...                                                        ...     ...   ...
# ...

# %%
#12
tab[(tab.Survived == 1) & ((tab.Class == 1) | (tab.Class == 2))]
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 12                  1      1
# 22                  1      2
# 24                  1      1
# ...               ...    ...
# 863                 1      1
# 872                 1      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
#13
tab['Female'] = tab.apply(lambda x:x['Sex'] == 'female',axis=1)
tab
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # Group

# %%
#1
tab.Embarked.unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
#2
tab.groupby(['Embarked']).mean()
# Out:
#           Survived     Class        Age     SibSp     Parch        Fare  \
# Embarked
# C         0.738462  1.030769  37.461538  0.415385  0.400000  103.342503
# Q         0.500000  1.000000  38.500000  1.500000  0.000000   90.000000
# S         0.637931  1.284483  34.624310  0.474138  0.525862   64.669216
#
#             Female
# Embarked
# C         0.523077
# Q         0.500000
# S         0.456897

# %%
#3
Sex = tab.groupby(['Sex']).mean()['Age']
Sex.describe()[['std','mean']]
# Out:
# std      4.084003
# mean    35.563963
# Name: Age, dtype: float64

# %% [markdown]
# # End

# %%
#1
tab.columns = map(str.lower, tab.columns)
tab
# Out:
#              survived  class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 11                  1      3
# 12                  1      1
# ...               ...    ...
# 872                 1      1
# 873                 0      1
# 880                 1      1
# 888                 1      1
# 890                 1      1
#
#                                                           name     sex   age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
#2
tab.to_csv('Titanic-new.csv')
